# %%
from multi_path_base import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b02199c9d2d2> in <module>
# ----> 1 from multi_path_base import *
#
# ModuleNotFoundError: No module named 'multi_path_base'

# %%
import pandas as pd
# %matplotlib tk 
from pandas import Series
import datetime as dt

# %%
Normalization=793.7
df = pd.read_csv('URUY_REAL.csv',parse_dates=[0])

# %%
df.columns.values[0]='Date'

# %%
X = df.values

# %%
X.shape

# %%
# %matplotlib tk 
plt.plot(X[10,1:]/Normalization)

# %%
X[0,0]

# %%
f = pd.read_fwf('sal_utep3_h72_2016_130317.txt',header=None)

# %%
p= f.values

# %%
f = pd.read_csv('sal_utep3_h72_2016_130317.txt', delimiter= '\s+', index_col=False,header=2)

# %%
f;

# %%
p= f.values

# %%
p

# %%
dt = dt.datetime.strptime("21/11/06 16:30", "%d/%m/%y %H:%M");dt

# %%
p[:,1]

# %%
p[0]

# %%
p[:,6] # time of forecast

# %%
p[:,2] # start of forecast

# %%
date_object = dt.strptime('01/01/16', "%d/%m/%y").date();
time_object = dt.strptime('1300', "%H%M").time();

# %%
combined = date.combine(date_object, time_object);combined

# %%
unix = combined.strftime('%s'); unix #convert to unix time

# %%
#dt.fromtimestamp(1451642400) recover the date and time

# %%
datetime_objects=np.empty(( len(p[:,1])), dtype='object')
datetime_unix=np.empty(( len(p[:,1])), dtype='object')

for i in range(0, len(p[:,1]) ):
    date_object = dt.strptime(p[i,1] , "%d/%m/%y").date()
    time_object = dt.strptime(format(p[i,6], '04d'), "%H%M").time()
    datetime_objects[i] = date.combine(date_object, time_object)
    datetime_unix[i] = datetime_objects[i].strftime('%s')

# %%
# %matplotlib tk 
plt.plot(datetime_unix)
